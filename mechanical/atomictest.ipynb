# %%
from numba import cuda, jit, prange, njit, int64
import numpy as np

# %%
@cuda.jit
def addNeighborhood(data_d, vals_d):
    i = cuda.grid(1)
    if i < data_d.shape[0]:
        val = cuda.atomic.compare_and_swap(data_d[i:], 0, 10)
        vals_d[i] = val

@cuda.jit
def setRanges(data_d):
    i = cuda.grid(1)
    datu = cuda.local.array(2, int64)
    datu[0] = i*2
    datu[1] = i*2+1
    if i < data_d.shape[0] // 2:
        data_d[i*2:i*2+2] = datu[:]
        
def testAtomic():
    data = np.zeros(10, np.int64)
    data[5] = 2
    data_d = cuda.to_device(data)
    vals_d = cuda.device_array(10, np.int64)
    addNeighborhood[1, 32](data_d, vals_d)
    return data_d.copy_to_host(), vals_d.copy_to_host()

def testSetRanges():
    data = np.full(10, -1, np.int64)
    data_d = cuda.to_device(data)
    setRanges[1, 32](data_d)
    return data_d.copy_to_host()

# %%
test1 = testAtomic()
test1
# Out:
# (array([10, 10, 10, 10, 10,  2, 10, 10, 10, 10], dtype=int64),
#  array([0, 0, 0, 0, 0, 2, 0, 0, 0, 0], dtype=int64))

# %%
test2 = testSetRanges()
test2
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\errors.py in new_error_context(fmt_, *args, **kwargs)
#     743     try:
# --> 744         yield
#     745     except NumbaError as e:
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower_block(self, block)
#     229                                    loc=self.loc, errcls_=defaulterrcls):
# --> 230                 self.lower_inst(inst)
#     231         self.post_block(block)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower_inst(self, inst)
#     382             assert signature is not None
# --> 383             return self.lower_setitem(inst.target, inst.index, inst.value,
#     384                                       signature)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower_setitem(self, target_var, index_var, value_var, signature)
#     475
# --> 476         return impl(self.builder, (target, index, value))
#     477
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\base.py in __call__(self, builder, args, loc)
#    1164     def __call__(self, builder, args, loc=None):
# -> 1165         res = self._imp(self._context, builder, self._sig, args, loc=loc)
#    1166         self._context.add_linking_libs(getattr(self, 'libs', ()))
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\base.py in wrapper(*args, **kwargs)
#    1194                 kwargs.pop('loc')     # drop unused loc
# -> 1195                 return fn(*args, **kwargs)
#    1196
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\np\arrayobj.py in setitem_array(context, builder, sig, args)
#     501         # (NOTE: this also handles scalar broadcasting)
# --> 502         return fancy_setslice(context, builder, sig, args,
#     503                               index_types, indices)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\np\arrayobj.py in fancy_setslice(context, builder, sig, args, index_types, indices)
#    1360
# -> 1361         src_getitem, src_cleanup = maybe_copy_source(context, builder, use_copy,
#    1362                                                      srcty, src, src_shapes,
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\np\arrayobj.py in maybe_copy_source(context, builder, use_copy, srcty, src, src_shapes, src_strides, src_data)
#    1174         allocsize = builder.mul(src.itemsize, src.nitems)
# -> 1175         data = context.nrt.allocate(builder, allocsize)
#    1176         voidptrty = data.type
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\runtime\context.py in allocate(self, builder, size)
#      22         """
# ---> 23         self._require_nrt()
#      24
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\runtime\context.py in _require_nrt(self)
#      16         if not self._enabled:
# ---> 17             raise RuntimeError("NRT required but not enabled")
#      18
#
# RuntimeError: NRT required but not enabled
#
# During handling of the above exception, another exception occurred:
#
# LoweringError                             Traceback (most recent call last)
# <ipython-input-50-23f766a04211> in <module>
# ----> 1 test2 = testSetRanges()
#       2 test2
#
# <ipython-input-48-efe1d56e2a7f> in testSetRanges()
#      24     data = np.full(10, -1, np.int64)
#      25     data_d = cuda.to_device(data)
# ---> 26     setRanges[1, 32](data_d)
#      27     return data_d.copy_to_host()
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\cuda\compiler.py in __call__(self, *args)
#     819
#     820     def __call__(self, *args):
# --> 821         return self.dispatcher.call(args, self.griddim, self.blockdim,
#     822                                     self.stream, self.sharedmem)
#     823
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\cuda\compiler.py in call(self, args, griddim, blockdim, stream, sharedmem)
#     962             kernel = next(iter(self.overloads.values()))
#     963         else:
# --> 964             kernel = _dispatcher.Dispatcher._cuda_call(self, *args)
#     965
#     966         kernel.launch(args, griddim, blockdim, stream, sharedmem)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\cuda\compiler.py in _compile_for_args(self, *args, **kws)
#     970         assert not kws
#     971         argtypes = [self.typeof_pyval(a) for a in args]
# --> 972         return self.compile(tuple(argtypes))
#     973
#     974     def _search_new_conversions(self, *args, **kws):
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\cuda\compiler.py in compile(self, sig)
#    1091             if not self._can_compile:
#    1092                 raise RuntimeError("Compilation disabled")
# -> 1093             kernel = _Kernel(self.py_func, argtypes, link=self.link,
#    1094                              **self.targetoptions)
#    1095             # Inspired by _DispatcherBase.add_overload, but differs slightly
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      33         def _acquire_compile_lock(*args, **kwargs):
#      34             with self:
# ---> 35                 return func(*args, **kwargs)
#      36         return _acquire_compile_lock
#      37
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\cuda\compiler.py in __init__(self, py_func, argtypes, link, debug, inline, fastmath, extensions, max_registers, opt)
#     507         self.extensions = extensions or []
#     508
# --> 509         cres = compile_cuda(self.py_func, types.void, self.argtypes,
#     510                             debug=self.debug,
#     511                             inline=inline)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      33         def _acquire_compile_lock(*args, **kwargs):
#      34             with self:
# ---> 35                 return func(*args, **kwargs)
#      36         return _acquire_compile_lock
#      37
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\cuda\compiler.py in compile_cuda(pyfunc, return_type, args, debug, inline)
#      45         flags.set('forceinline')
#      46     # Run compilation pipeline
# ---> 47     cres = compiler.compile_extra(typingctx=typingctx,
#      48                                   targetctx=targetctx,
#      49                                   func=pyfunc,
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     604     pipeline = pipeline_class(typingctx, targetctx, library,
#     605                               args, return_type, flags, locals)
# --> 606     return pipeline.compile_extra(func)
#     607
#     608
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler.py in compile_extra(self, func)
#     351         self.state.lifted = ()
#     352         self.state.lifted_from = None
# --> 353         return self._compile_bytecode()
#     354
#     355     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler.py in _compile_bytecode(self)
#     413         """
#     414         assert self.state.func_ir is None
# --> 415         return self._compile_core()
#     416
#     417     def _compile_ir(self):
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler.py in _compile_core(self)
#     393                 self.state.status.fail_reason = e
#     394                 if is_final_pipeline:
# --> 395                     raise e
#     396         else:
#     397             raise CompilerError("All available pipelines exhausted")
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler.py in _compile_core(self)
#     384             res = None
#     385             try:
# --> 386                 pm.run(self.state)
#     387                 if self.state.cr is not None:
#     388                     break
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_machinery.py in run(self, state)
#     337                     (self.pipeline_name, pass_desc)
#     338                 patched_exception = self._patch_error(msg, e)
# --> 339                 raise patched_exception
#     340
#     341     def dependency_analysis(self):
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_machinery.py in run(self, state)
#     328                 pass_inst = _pass_registry.get(pss).pass_inst
#     329                 if isinstance(pass_inst, CompilerPass):
# --> 330                     self._runPass(idx, pass_inst, state)
#     331                 else:
#     332                     raise BaseException("Legacy pass in use")
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      33         def _acquire_compile_lock(*args, **kwargs):
#      34             with self:
# ---> 35                 return func(*args, **kwargs)
#      36         return _acquire_compile_lock
#      37
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     287             mutated |= check(pss.run_initialization, internal_state)
#     288         with SimpleTimer() as pass_time:
# --> 289             mutated |= check(pss.run_pass, internal_state)
#     290         with SimpleTimer() as finalize_time:
#     291             mutated |= check(pss.run_finalizer, internal_state)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\compiler_machinery.py in check(func, compiler_state)
#     260
#     261         def check(func, compiler_state):
# --> 262             mangled = func(compiler_state)
#     263             if mangled not in (True, False):
#     264                 msg = ("CompilerPass implementations should return True/False. "
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\typed_passes.py in run_pass(self, state)
#     461
#     462         # TODO: Pull this out into the pipeline
# --> 463         NativeLowering().run_pass(state)
#     464         lowered = state['cr']
#     465         signature = typing.signature(state.return_type, *state.args)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\typed_passes.py in run_pass(self, state)
#     382                 lower = lowering.Lower(targetctx, library, fndesc, interp,
#     383                                        metadata=metadata)
# --> 384                 lower.lower()
#     385                 if not flags.no_cpython_wrapper:
#     386                     lower.create_cpython_wrapper(flags.release_gil)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower(self)
#     134         if self.generator_info is None:
#     135             self.genlower = None
# --> 136             self.lower_normal_function(self.fndesc)
#     137         else:
#     138             self.genlower = self.GeneratorLower(self)
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower_normal_function(self, fndesc)
#     188         # Init argument values
#     189         self.extract_function_arguments()
# --> 190         entry_block_tail = self.lower_function_body()
#     191
#     192         # Close tail of entry block
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower_function_body(self)
#     214             bb = self.blkmap[offset]
#     215             self.builder.position_at_end(bb)
# --> 216             self.lower_block(block)
#     217         self.post_lower()
#     218         return entry_block_tail
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\lowering.py in lower_block(self, block)
#     228             with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     229                                    loc=self.loc, errcls_=defaulterrcls):
# --> 230                 self.lower_inst(inst)
#     231         self.post_block(block)
#     232
#
# ~\anaconda3\envs\igl\lib\contextlib.py in __exit__(self, type, value, traceback)
#     133                 value = type()
#     134             try:
# --> 135                 self.gen.throw(type, value, traceback)
#     136             except StopIteration as exc:
#     137                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\anaconda3\envs\igl\lib\site-packages\numba\core\errors.py in new_error_context(fmt_, *args, **kwargs)
#     749         newerr = errcls(e).add_context(_format_msg(fmt_, args, kwargs))
#     750         tb = sys.exc_info()[2] if numba.core.config.FULL_TRACEBACKS else None
# --> 751         raise newerr.with_traceback(tb)
#     752
#     753
#
# LoweringError: Failed in nopython mode pipeline (step: nopython mode backend)
# NRT required but not enabled
#
# File "<ipython-input-48-efe1d56e2a7f>", line 14:
# def setRanges(data_d):
#     <source elided>
#     if i < data_d.shape[0] // 2:
#         data_d[i*2:i*2+2] = datu[:]
#         ^
#
# During: lowering "data_d[$100build_slice.16] = $80binary_subscr.5" at <ipython-input-48-efe1d56e2a7f> (14)
